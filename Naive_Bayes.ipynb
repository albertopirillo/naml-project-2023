# %% [markdown]
# # Naive Bayes

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# Load and pre-process the dataset:

# %%
from lib import pre_processing
file_path = "./data/features_3_sec.csv"
df = pd.read_csv(file_path)
df = pre_processing(df)

# %% [markdown]
# ## Data Normalization

# %%
from lib import normalize_df
df = normalize_df(df)

# %%
df_numpy = df.to_numpy()
X = df_numpy[:,:-1]
y = df_numpy[:, -1]

# %%
X.shape, y.shape
# Out:
# ((9990, 57), (9990,))

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Multiclass classifier

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

def fit_gnb(X, y, test_size):
    # Train-validation split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
    
    # Fit the model and compute predictions
    gnb = GaussianNB()
    gnb = gnb.fit(X_train, y_train)
    y_pred = gnb.predict(X_test)
    
    # Return the accuracy
    return np.sum(y_test == y_pred) / len(y_test)

# %%
accuracy = fit_gnb(X, y, 0.25)
print(f"| Genre: multiclass | Accuracy: {accuracy:.3%} |")
# Out:
# | Genre: multiclass | Accuracy: 52.002% |

# %% [markdown]
# ### Balanced Binary Classifiers

# %%
genres = ['blues', 'classical', 'country', 'disco', 'hiphop','jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
from lib import balance_classes
for genre in genres:
    Xi, yi = balance_classes(X, y, genre)
    accuracy = fit_gnb(Xi, yi, 0.25)
    print(f"| Genre: {genre:9} | Accuracy: {accuracy:.3%} |")
# Out:
# | Genre: blues     | Accuracy: 78.200% |
# | Genre: classical | Accuracy: 90.581% |
# | Genre: country   | Accuracy: 72.946% |
# | Genre: disco     | Accuracy: 71.400% |
# | Genre: hiphop    | Accuracy: 76.954% |
# | Genre: jazz      | Accuracy: 81.200% |
# | Genre: metal     | Accuracy: 87.400% |
# | Genre: pop       | Accuracy: 84.200% |
# | Genre: reggae    | Accuracy: 82.600% |
# | Genre: rock      | Accuracy: 70.741% |

# %% [markdown]
# ### Cross-validation

# %%
from sklearn.model_selection import KFold

def cross_validate(X, y, n_splits):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=0)
    accuracy_list = []
    
    for train, test in kf.split(X):
        X_train, X_test, y_train, y_test = X[train], X[test], y[train], y[test]

        # Fit the model and compute predictions
        gnb = GaussianNB()
        gnb = gnb.fit(X_train, y_train)
        y_pred = gnb.predict(X_test)

        accuracy = np.sum(y_test == y_pred) / len(y_test)
        accuracy_list.append(accuracy)
        
    return np.mean(accuracy_list)

# %% [markdown]
# ## Static partitioning (train-validation split)

# %%
test_sizes = [0.1, 0.25, 0.33]

# %%
from lib import plot_evaluation_results
sp_results = []

for test_size in test_sizes:
    # Multiclass classifier
    accuracy = fit_gnb(X, y, test_size)
    sp_results.append(('multiclass', accuracy*100, f'Test size {test_size}'))
    
    # Binary classifiers
    for genre in genres:
        Xi, yi = balance_classes(X, y, genre)
        accuracy = fit_gnb(Xi, yi, test_size)
        sp_results.append((genre, accuracy*100, f'Test size {test_size}'))
    
# Plot
results_df = pd.DataFrame(sp_results, columns=['label', 'accuracy', 'size'])
plot_evaluation_results(results_df, f"Naive Bayes Classification - Train-validation split")

# %% [markdown]
# ## Dynamic partitioning (cross-validation)

# %%
folds = [5, 10, 20]

# %%
sp_results = []

for fold in folds:
    # Multiclass classifier
    accuracy = cross_validate(X, y, fold)
    sp_results.append(('multiclass', accuracy*100, f'{fold}-fold CV'))
    
    # Binary classifiers
    for genre in genres:
        Xi, yi = balance_classes(X, y, genre)
        accuracy = cross_validate(Xi, yi, fold)
        sp_results.append((genre, accuracy*100, f'{fold}-fold CV'))
    
# Plot
results_df = pd.DataFrame(sp_results, columns=['label', 'accuracy', 'size'])   
plot_evaluation_results(results_df, f"Naive Bayes Classification - Cross-validation")

# %% [markdown]
# # Multiclass confusion matrix

# %%
from lib import plot_confusion_matrix
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
gnb = GaussianNB()
gnb = gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
plot_confusion_matrix(y_test, y_pred, genres)
